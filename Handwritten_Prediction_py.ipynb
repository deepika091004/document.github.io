# %% [markdown]
# <a href="https://colab.research.google.com/github/deepika091004/document.github.io/blob/main/Handwritten_Prediction_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Hand written prediction
#Importing necesary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
# Load the MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Normalize the pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the 2D images into 1D
    layers.Dense(128, activation='relu'),  # Add a fully connected layer with 128 units
    layers.Dropout(0.2),                   # Add dropout for regularization
    layers.Dense(10, activation='softmax') # Output layer with 10 units (one for each digit)
])
#Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
#Train the model
model.fit(x_train, y_train, epochs=5)
#Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc}')
#Make predictions
predictions = model.predict(x_test)
# Display the first 5 predictions
for i in range(5):
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.title(f'Prediction: {np.argmax(predictions[i])}, Actual: {y_test[i]}')
    plt.show()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2930 - accuracy: 0.9140
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1386 - accuracy: 0.9579
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1050 - accuracy: 0.9679
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0852 - accuracy: 0.9738
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0730 - accuracy: 0.9768
# 313/313 - 1s - loss: 0.0784 - accuracy: 0.9763 - 569ms/epoch - 2ms/step
# Test accuracy: 0.9763000011444092
# 313/313 [==============================] - 1s 2ms/step
